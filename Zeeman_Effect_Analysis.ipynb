# %%
import matplotlib.pyplot as plt
import numpy as np

B = [330, 1120, 1363, 2100, 2730, 3370, 3950, 4520, 5150, 5650, 6240, 6850, 7300, 7750, 8080, 8450, 8750] # Guass
I = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.40, 0.45, 0.5, 0.55, 0.60, 0.65, 0.70, 0.75, 0.80] # Amps
V =[0, 15, 20, 25, 37, 42.5, 55, 65, 75, 85, 95, 105, 115, 125, 135, 145, 155] # V


plt.Figure(figsize=(12, 6))
plt.plot(B, I, 'k.')

# Fit a line to the data
a,b = np.polyfit(B[:-3], I[:-3], 1)

plt.plot(B, a*np.array(B) + b, 'b-', label='Linear fit y = {:.5f}x - {:.2f}'.format(a,-b))

plt.errorbar(B, I, xerr=100, yerr=0.025, fmt='k.', label='Experimental Data')

plt.xlabel('Magnetic Field (Gauss)')
plt.ylabel('Current (Amps)')
plt.title('Current vs Magnetic Field')
plt.legend()

plt.savefig('current_vs_magnetic_field.png')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[31], line 24
#      21 plt.title('Current vs Magnetic Field')
#      22 plt.legend()
# ---> 24 plt.savefig('current_vs_magnetic_field.png')
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py:1243, in savefig(*args, **kwargs)
#    1240 fig = gcf()
#    1241 # savefig default implementation has no return, so mypy is unhappy
#    1242 # presumably this is here because subclasses can return?
# -> 1243 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1244 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1245 return res
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
# ...
